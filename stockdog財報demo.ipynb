# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.stockdog.com.tw/stockdog/index.php?m=overview&sid=2049'
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.2564.116 Safari/537.36'}

rs = requests.session()  #用rs存取第一面的資料

res = rs.get(url, headers = headers)

import re
m = re.findall('document.getElementById\(\'g\d+\'\).innerHTML=\'<iframe src=\"(.*?)\"',res.text)
#  \"(.*?)\" 任意網址
#  \(\'g\d+\'\) 忽略符號+任意數字/d
#for url in m:
    #print "https://www.stockdog.com.tw/stockdog/" +url

#print "https://www.stockdog.com.tw/stockdog/" +m[0]

res2 = rs.get("https://www.stockdog.com.tw/stockdog/" +m[0], headers = headers)    
print res2.text
# Out:
# ﻿<!DOCTYPE HTML>
# <html>
# <head>
# <meta http-equiv=Content-Type content="text/html; charset=utf-8">
# <title>2016-02-19 上銀(2049) 走勢圖</title>
# <script type=text/javascript src=js/jquery/1.8.2/jquery.min.js></script>
# ...
