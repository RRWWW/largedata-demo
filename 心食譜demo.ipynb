# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get("http://www.xinshipu.com/zuofa/222290")
soup = BeautifulSoup(res.text)
print soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//EN" "http://www.w3.org/TR/xhtml11/DTD/xhtml11.dtd">
# <html>
# <head>
# <meta content="麻辣白切鸡,麻辣白切鸡的做法,麻辣白切鸡怎么做" name="keywords"/>
# <meta content="1、鸡清洗干净，锅中放入水（没过鸡），加入生姜、桂皮、香叶，大火烧开，转小火煮30分钟左右。2、取出鸡，切片，摆入盘中。3、制作麻辣汁：生抽、辣椒油少许、盐、鸡精适量混合均匀。" name="description"/>
# <meta content="article" property="og:type"/></head><body><p>
# 　　 <meta content="2013-10-06T16:10:00+08:00" property="article:published_time"/>
# 　　 <meta content="AXL" property="article:author"/>
# 　　 <meta content="心食谱,http://m.xinshipu.com/zuofa/222290" property="article:published_first"/>
# </p><title>麻辣白切鸡的做法_麻辣白切鸡怎么做_麻辣白切鸡的家常做法【心食谱】</title>
# <meta charset="utf-8"/>
# <meta content="zh-CN" http-equiv="Content-Language"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width" name="MobileOptimized"/>
# <meta name="google" value="notranslate"/>
# <meta content="no-siteapp" http-equiv="Cache-Control"/>
# <meta content="mobile" name="applicable-device"/>
# <link href="http://xinshipu.cn/2014/css/img/xsp.ico" rel="shortcut icon"/>
# <link href="http://xinshipu.cn/2014/css/img/touch-icon-iphone.png" rel="apple-touch-icon"/>
# <link href="http://xinshipu.cn/2014/css/img/touch-icon-ipad.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="http://xinshipu.cn/2014/css/img/touch-icon-iphone-retina.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="http://xinshipu.cn/2014/css/img/touch-icon-ipad-retina.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="http://xinshipu.cn/2014/css/xspxsp.highendmobile.20141015.min.css" rel="stylesheet" type="text/css"/>
# <style>
# .word-link-list li{padding: 18px 24px 18px 0;}
# #adBottom {
# left:0;
# position: fixed;
# text-align:center;
# bottom: 0px;
# width:100%;
# height:120px
# }
# </style>
# <script src="http://xinshipu.cn/js/inc.20151111.js"></script>
# <script type="text/javascript">
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#   ga('create', 'UA-11253628-8', 'xinshipu.com');
#
# 	ga('set', 'dimension1', 'test');
#
# 	ga('send', 'pageview');
# </script>
# <script>
# 			function isLogin(){
# 				var user =  eval({"is_login":0});
# 				return user;
# 			}
# 			var _config = {
# 				'isv_userinfo': function(){
# 					return isLogin();
# 				}
# 			};
# 		</script>
# <div class="w tc header" style="position:fixed;  z-index: 999;">
# <!--BEGIN TOP -->
# <div class="top">
# <div class="mlr4 h50">
# <div class="logo">
# <h1><a href="/" target="_self"><span>心食谱</span></a></h1>
# </div>
# <a class="search-fold" href="#q" onclick="document.getElementById('q').focus();return false;"><i class="icon-font icon-search"></i></a>
# <div class="fr menu-r"><a class="more-menu" href="#q"><span class="icon-menu"> </span></a></div>
# </div>
# </div>
# <!--END TOP -->
# <div class="w tl nav hideNav-new"></div>
# </div>
# <div class="content" itemscope="" itemtype="http://schema.org/Recipe">
# <h1 class="font16 h47 tc cg1" itemprop="name">麻辣白切鸡</h1>
# <hr/>
# <div class="mlr1 mt14 new-menu-pic"><img itemprop="image" src="http://ama.xinshipu.cn/20131006/original/1381047988387.jpg@300w_225h_90q_1e_1c.jpg"/></div>
# <div class="p01bgf">
# <h2 class="subtitle cg1">材料</h2>
# </div>
# <div itemprop="ingredients">
# <p class="ptm12 mlr1 btm"><a class="orange-bottom" href="/caipu/8471/" rel="CaiLiaoClicked" title="鸡做法大全"><span class="ingredient"><span class="name">鸡</span></span></a>半只，葱，姜，<a class="orange-bottom" href="/zuofadaquan/5464/" rel="CaiLiaoClicked" title="八角做法大全"><span class="ingredient"><span class="name">八角</span></span></a>，<a class="orange-bottom" href="/zuofadaquan/999/" rel="CaiLiaoClicked" title="桂皮做法大全"><span class="ingredient"><span class="name">桂皮</span></span></a>，<a class="orange-bottom" href="/zuofadaquan/8145/" rel="CaiLiaoClicked" title="香叶做法大全"><span class="ingredient"><span class="name">香叶</span></span></a>，<a class="orange-bottom" href="/zuofadaquan/3533/" rel="CaiLiaoClicked" title="花椒粒做法大全"><span class="ingredient"><span class="name">花椒粒</span></span></a>，<a class="orange-bottom" href="/zuofadaquan/1097/" rel="CaiLiaoClicked" title="白芝麻做法大全"><span class="ingredient"><span class="name">白芝麻</span></span></a>，蒜末，<a class="orange-bottom" href="/zuofadaquan/8151/" rel="CaiLiaoClicked" title="香菜做法大全"><span class="ingredient"><span class="name">香菜</span></span></a>，<a class="orange-bottom" href="/zuofadaquan/330/" rel="CaiLiaoClicked" title="辣椒油做法大全"><span class="ingredient"><span class="name">辣椒油</span></span></a>，<a class="orange-bottom" href="/zuofadaquan/3497/" rel="CaiLiaoClicked" title="生抽做法大全"><span class="ingredient"><span class="name">生抽</span></span></a>，盐适量</p>
# </div>
# <div class="p01bgf" itemprop="recipeInstructions">
# <h2 class="subtitle cg1">做法</h2>
# </div>
# <div class="pm12">
# <div class="mlr1 bbm">
# </p>
# </p>
# </p>
# </p>
# <p>5、锅内热油，放入蒜末、花椒粒、芝麻爆香，淋在鸡肉上，撒上香菜即可。</p>
# <center>
# <script async="" src="http://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- 移动广告 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-1301161247680439" data-ad-slot="2554907909" style="display:inline-block;width:300px;height:250px"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </center><hr class="mt20"/>
# <div class="clearfix store-block">
# <div class="fl">
# <div class="h-pw clearfix mt12">
# <a class="cb" href="/chufang/332670/" rel="nofollow">
# <img class="photo24" src="http://ama.xinshipu.cn/css/img/nophoto.jpg@24w_24h_99q_1e_1c"/>
# <span itemprop="name">AXL</span>
# <i class="icon-vip col"></i></a>
# </div>
# <span itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating">
# <span itemprop="ratingValue">5.0</span>分
#           			<span itemprop="reviewCount">3</span>位评价
#       			</span>
# </div>
# <input id="bookmarked" type="hidden" value=""/>
# <input id="anonymityFavorites" type="hidden" value=""/>
# <form action="/api/doShouCang.html" id="searchform" method="get">
# <input id="shipuid" name="shipuid" type="hidden" value="222290"/>
# <input id="shipuname" name="shipuname" type="hidden" value="麻辣白切鸡"/>
# <div class="fr"><button class="o-btn store-menu" type="submit">收藏食谱</button></div>
# </form>
# </div>
# <hr class="mt20"/>
# </div>
# </div>
# <div class="mlr1">
# <h2 class="subtitle cg1">相关食谱</h2>
# <div class="scroll-pic mt-12">
# <ul class="col3 relate-menu">
# <li>
# <a href="/zuofa/10011" rel="ShipuInGridClicked">
# <div class="v-pw">
# <img alt="酸辣白切鸡+瓜龙的切法" src="http://ama.xinshipu.cn/20100325/original/1269463262770.jpg@196w_126h_90q_1e_1c.jpg" title="酸辣白切鸡+瓜龙的切法"/>
# <div class="v-pw-w">酸辣白切鸡+瓜龙的切法</div>
# </div>
# </a>
# </li><li>
# <a href="/zuofa/173021" rel="ShipuInGridClicked">
# <div class="v-pw">
# <img alt="麻辣鸡块" src="http://ama.xinshipu.cn/20130228/original/1362038934356.jpg@196w_126h_90q_1e_1c.jpg" title="麻辣鸡块"/>
# <div class="v-pw-w">麻辣鸡块</div>
# </div>
# </a>
# </li><li>
# <a href="/zuofa/178351" rel="ShipuInGridClicked">
# <div class="v-pw">
# <img alt="麻辣鸡脚" src="http://ama.xinshipu.cn/20130228/original/1362052760940.jpg@196w_126h_90q_1e_1c.jpg" title="麻辣鸡脚"/>
# <div class="v-pw-w">麻辣鸡脚</div>
# </div>
# </a>
# </li></ul>
# </div>
# </div>
# <div class="mlr1">
# <h2 class="subtitle cg1">推荐食谱</h2>
# <div class="scroll-pic mt-12">
# <ul class="col3 relate-menu">
# <li>
# <a href="/zuofa/1289" rel="ShipuInGridClicked">
# <div class="v-pw">
# <img alt="红烧带鱼" src="http://ama.xinshipu.cn/20100323/original/1269317360145.jpg@196w_126h_90q_1e_1c.jpg" title="红烧带鱼"/>
# <div class="v-pw-w">红烧带鱼</div>
# </div>
# </a>
# </li><li>
# <a href="/zuofa/15796" rel="ShipuInGridClicked">
# <div class="v-pw">
# <img alt="芹菜炒牛肉" src="http://ama.xinshipu.cn/20100325/original/1269497202473.jpg@196w_126h_90q_1e_1c.jpg" title="芹菜炒牛肉"/>
# <div class="v-pw-w">芹菜炒牛肉</div>
# </div>
# </a>
# </li><li>
# <a href="/zuofa/232906" rel="ShipuInGridClicked">
# <div class="v-pw">
# <img alt="酸菜鱼" src="http://ama.xinshipu.cn/20140201/original/1391210725500.jpg@196w_126h_90q_1e_1c.jpg" title="酸菜鱼"/>
# <div class="v-pw-w">酸菜鱼</div>
# </div>
# </a>
# </li></ul>
# </div>
# </div>
# <div class="mlr1">
# <h2 class="subtitle cg1">美食问答</h2>
# </div>
# <div class="btm">
# <ul class="mlr1 word-link-list">
# <a href="/question/29614"><li>白切鸡怎么做</li></a>
# <div class="bbt"></div><a href="/question/26123"><li>我问白切鸡用老母鸡能做吗？</li></a>
# <div class="bbt"></div><a href="/question/34005"><li>白切鸡用什么鸡</li></a>
# <div class="bbt"></div><a href="/question/34062"><li>白切鸡怎么做</li></a>
# <div class="bbt"></div><a href="/question/36226"><li>如何做白切雞沾醬
# </li></a>
# </ul>
# </div>
# <div class="mlr1">
# <h2 class="subtitle cg1">小知识</h2>
# </div>
# <div class="btm">
# <ul class="mlr1 word-link-list">
# <a href="/zuofa/116099"><li>关于煮牛肉的一些窍门</li></a>
# <div class="bbt"></div><a href="/zuofa/116215"><li>麻麻辣味调制</li></a>
# <div class="bbt"></div><a href="/zuofa/136289"><li>麻辣香锅怎么吃不上火</li></a>
# <div class="bbt"></div><a href="/zuofa/144104"><li>吃麻辣烫时的注重事项</li></a>
# <div class="bbt"></div><a href="/zuofa/135324"><li>吃麻辣烫的五点必知</li></a>
# </ul>
# </div>
# <div class="mlr1">
# <h2 class="subtitle cg1">厨友分类</h2>
# <ul class="gb-link-list mt-12">
# <li><a class="fenlei" href="/caipu/10954/" trackinfo="1">白切鸡</a></li>
# <li><a class="fenlei" href="/caipu/112164/" trackinfo="2">麻辣</a></li>
# <li><a class="fenlei" href="/caipu/8471/" trackinfo="3">鸡</a></li>
# </ul>
# </div>
# <div class="mlr1">
# <h2 class="subtitle cg1">相关搜索</h2>
# <ul class="gb-link-list mt-12">
# </ul>
# </div>
# </div>
# <div class="search-wrap" id="searchbox">
# <div class="search mlr1">
# <!--BEGIN SEARCH MOD -->
# <div class="search-mod">
# <div class="search-pannel">
# <form action="/doSearch.html" method="get" name="search" target="_top">
# <div class="search-btn">
# <button onclick="javascript:ga('send', 'event', 'header', 'QuerySubmit',$('#q').val());window.location.href='/doSearch.html?q='+encodeURI($.trim($('#q').val()));return false;" type="submit">搜索</button>
# </div>
# <div class="search-panel-fields">
# <label for="searchVal">
# </label>
# <div class="search-combobox"><div class="search-combobox-input-wrap">
# <input accesskey="s" class="search-combobox-input font16" id="q" name="q" type="text" value="麻辣白切鸡"/>
# </div></div>
# </div>
# </form>
# </div>
# </div>
# <!--END SEARCH MOD -->
# </div>
# </div>
# <div class="footer-nav btm" id="footer_menu" name="footer_menu">
# <ul class="word-link-list mlr1">
# <a href="/%E8%8F%9C%E8%B0%B1%E5%A4%A7%E5%85%A8.html"><li>菜谱大全</li></a>
# <div class="bbt"></div>
# <a href="/%E5%AE%B6%E5%B8%B8%E8%8F%9C.html"><li>家常菜谱</li></a>
# <div class="bbt"></div>
# <a href="/question/"><li>美食问答</li></a>
# <div class="bbt"></div>
# <a href="/%E9%A5%AE%E9%A3%9F%E5%81%A5%E5%BA%B7.html"><li>健康食疗</li></a>
# <div class="bbt"></div>
# <a href="/chuyoufenlei/"><li>食谱分类</li></a>
# <div class="bbt"></div>
# <a href="/usertop/"><li>厨友排行</li></a>
# <div class="bbt"></div>
# <a href="/highendmobile2014/login.highendmobile.html?from=/zuofa/222290" rel="nofollow"><li>登录</li></a>
# <div class="bbt"></div>
# <a href="/highendmobile2014/registre.highendmobile.html?from=/zuofa/222290" rel="nofollow"><li>注册</li></a>
# <div class="bbt"></div>
# <br/><br/>
# <div class="tc">
# 						©2016 xinshipu.com, all rights reserved.
# 						</div>
# </ul>
# <br/>
# </div>
# <script src="http://ajax.googleapis.com/ajax/libs/jquery/2.0.3/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# document.cookie="window_width="+$(window).width();
# </script><script type="text/javascript">
# 		function getTrackInfo(link){
# 			return decodeURIComponent(window.location)+'|'+link.attr('trackinfo')+'|'+decodeURIComponent(link.attr('href'))
# 		}
# 		$('.fenlei').click(function(){
# 			ga('send', 'event', 'zuofa', 'FenLeiClk', getTrackInfo($(this)));
#   		});
# 	</script>
# </body></html>

# %%
reup = soup.select('.re-up')[0] #卡關
print reup.select('.font18.no-overflow')[0].text
print reup.select('.font16.ml10.col')[0].text
print reup.select('.font16.ml10.col')[1].text
print reup.select('.cg2.mt12 span:nth-of-type(2)')[0].text
print reup.select('.cg2.mt12 span:nth-of-type(4)')[0].text
print reup.select('.cg2.mt12 span:nth-of-type(6)')[0].text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-2ed25f5650bf> in <module>()
# ----> 1 reup = soup.select('.re-up')[0]
#       2 print reup
#
# IndexError: list index out of range
