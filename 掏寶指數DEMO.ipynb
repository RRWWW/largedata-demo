# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7 ]>
# <html class="no-js ie6"> <![endif]-->
# <!--[if IE 7 ]>
# <html class="no-js ie7"> <![endif]-->
# <!--[if IE 8 ]>
# <html class="no-js ie8"> <![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!-->
# <html class="no-js"> <!--<![endif]-->
# <!-- the "no-js" class is for Modernizr. -->
# <head>
#     <meta charset="utf-8">
#     <!-- Always force latest IE rendering engine (even in intranet) & Chrome Frame
#      Remove this if you use the .htaccess -->
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
# <meta name="description" content="淘宝指数, 淘宝消费者数据研究平台" />
# <meta name="author" content="shu@taobao.com" />
# <title>淘宝指数 - 淘宝消费者数据研究平台</title>
# <link rel="stylesheet" href="http://static.data.taobaocdn.com/up/tbindexstatic/assets/styles/common.min.b6cf3fe2.css" media="all" />
#
#
#
# <script src="http://static.data.taobaocdn.com/up/tbindexstatic/assets/scripts/common.min.58ab861a.js"></script>
#
# <script>
#   var App = new Scape();
# ...

# %%
headers = {
'Cookie':'cna=JkHoDr/bJWYCAW/8JfMnr/mF; miid=7589044712665922684; _ga=GA1.2.577684731.1455112821; thw=tw; _m_h5_tk=2500a02d256aa75d21659e4fa8f10688_1455949702402; _m_h5_tk_enc=d49adb26b2f811b05db34748a80683dc; sc4=1; v=0; _tb_token_=FW3OUOmT78uEE; hng=TW%7Czh-tw%7CTWD; sc5=159UW5TcyMNYQwiAiwQRHhBfEF8QXtHcklnMWc%3D%7CUm5OcktzSHZCekF9RXxHcyU%3D%7CU2xMHDJ7G2AHYg8hAS8WIw0tA18%2BWDRTLVd5L3k%3D%7CVGhXd1llXGRfYVVtVmpSa1BtWmdFcUV4RHpPcEl0SHBFfUV%2FS2Uz%7CVWldfS0SMg04BSUePhAgBCAdbFJ8Knw%3D%7CVmNDbUMV%7CV2NDbUMV%7CWGZGFisLNhYqFiMfPws%2FASEdKRYrCzcKPwIiHioVKAg0CTwBVwE%3D%7CWWVYeFYGMw03CSl%2BUGxVbVVhX2tTal5nXGgdIAI3DjoBPwQ6ADgHOgI6DjIMW3VVaT8RRw%3D%3D%7CWmNDEz0TMww2CioTLw80DDVjNQ%3D%3D%7CW2JCEjwSMgwxCioQKws%2BADlvOQ%3D%3D%7CXGVFFTsVNQw0Di4RLho6DjAJXwk%3D%7CXWVFFTtBPFUuUypDLEFvTx8mGDgAOABWdktrRWtLcER%2BRhBG%7CXmZGFjgWNmZealZ2QnhBFzcKKgQqCj8COgFXAQ%3D%3D%7CX2dHFzkXN2dfY119Q35DY1puW3lBYV5qV3dPclJuVAIiHz8RPx8jHCAbJ3En%7CQHlEeVlkRHtbZ15iQnxEfl5mUnJIcFBvT3tEZF5%2BRWVdfUF%2FX2NcfEB8Kg%3D%3D; sc1=s%3Al90JAqnAecrHEgKfN8Lc6vNj.yJzk4waVF6mpPXr8Tp7gX0KTEoqL0TTx%2FPs%2BRBHQ5fY; uc1=cookie14=UoWyiPlFd8UTjw%3D%3D&existShop=false&cookie16=WqG3DMC9UpAPBHGz5QBErFxlCA%3D%3D&cookie21=UtASsssmfufd&tag=7&cookie15=Vq8l%2BKCLz3%2F65A%3D%3D&pas=0; uc3=sg2=UtU%2Ff0%2FBtBTssWemsLazJ0BTCru9NIJC8%2BBBOY%2FdKDg%3D&nk2=pfl4NM%2FuFnQP04rT&id2=UUBZFmxhyO3jLQ%3D%3D&vt3=F8dAScn1kOiTzxkvj7I%3D&lg2=VT5L2FSpMGV7TQ%3D%3D; existShop=MTQ1NjM5NTY2NA%3D%3D; uss=Wvi%2F%2FxOwf8eZDc6RFwKVf72L2hii7wwdV7hvIG0GjdxuQbZvTqwfAZN2; lgc=%5Cu82F9%5Cu679C%5Cu7EA2916818; tracknick=%5Cu82F9%5Cu679C%5Cu7EA2916818; sg=885; cookie2=1c47674c1e944e2fdffd1fe99e07784d; mt=np=&ci=0_1; cookie1=W8HbOXfkQtUwVwhXASdxzB78jV%2B%2Fzc4X08Gl0RTblTw%3D; unb=2817031238; t=613fc18683e65e683652705a235d0ed8; _cc_=UIHiLt3xSw%3D%3D; tg=5; _l_g_=Ug%3D%3D; _nk_=%5Cu82F9%5Cu679C%5Cu7EA2916818; cookie17=UUBZFmxhyO3jLQ%3D%3D; l=Ajk51cFHkNsoA33QIoDzXpoEya8TRi34',
'Host':'shu.taobao.com',
'Upgrade-Insecure-Requests':'1',
'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.2564.116 Safari/537.36',    
}

# %%
res2 = rs.get('http://shu.taobao.com/trendindex?spm=0.0.0.0.2BP9D3&query=iphone4&type=trade',headers = headers)
print res2.text
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7 ]>
# <html class="no-js ie6"> <![endif]-->
# <!--[if IE 7 ]>
# <html class="no-js ie7"> <![endif]-->
# <!--[if IE 8 ]>
# <html class="no-js ie8"> <![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!-->
# <html class="no-js"> <!--<![endif]-->
# <!-- the "no-js" class is for Modernizr. -->
# <head>
#     <meta charset="utf-8">
#     <!-- Always force latest IE rendering engine (even in intranet) & Chrome Frame
#      Remove this if you use the .htaccess -->
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
# <meta name="description" content="淘宝指数, 淘宝消费者数据研究平台" />
# <meta name="author" content="shu@taobao.com" />
# <title>iphone4 - 淘宝指数 - 淘宝消费者数据研究平台</title>
# <link rel="stylesheet" href="http://static.data.taobaocdn.com/up/tbindexstatic/assets/styles/common.min.b6cf3fe2.css" media="all" />
#
#
#   <link rel="stylesheet" href="http://static.data.taobaocdn.com/up/tbindexstatic/assets/styles/detail.min.820a5e6c.css" media="all" />
#
#
#
# ...

# %%
import re #正規表示法
help(re)
# Out:
# Help on module re:
#
# NAME
#     re - Support for regular expressions (RE).
#
# FILE
#     e:\anaconda2\lib\re.py
#
# DESCRIPTION
#     This module provides regular expression matching operations similar to
#     those found in Perl.  It supports both 8-bit and Unicode strings; both
#     the pattern and the strings being processed can contain null bytes and
#     characters outside the US ASCII range.
#
#     Regular expressions can contain both special and ordinary characters.
#     Most ordinary characters, like "A", "a", or "0", are the simplest
#     regular expressions; they simply match themselves.  You can
#     concatenate ordinary characters, so last matches the string 'last'.
#
#     The special characters are:
#         "."      Matches any character except a newline.
#         "^"      Matches the start of the string.
#         "$"      Matches the end of the string or just before the newline at
#                  the end of the string.
# ...

# %%
m = re.search('App.set\("trend", Index.convert\((.*)?\)\)', res2.text)
print m.group(1)
# Out:
# {"details":[{"age":[3576,52294,42541,24550,15822,22932,4741,2076],"career":[0,82589,19660],"constellation":[13093,13368,14307,12473,12723,11626,14887,13155,16518,16769,15571,14042],"consumption":[7834,48847,101377,29878,10224],"credit":[46065,83877,32880,20543,8196],"interest":[6254,37894,23754,17501,11177,15174,11466,8725,13104,17074,4875],"sex":[125158,43374],"province":[8817,2760,7094,3657,2076,5204,2662,3883,7932,15605,17741,6096,9362,4008,15552,7331,5823,5608,44380,8780,1440,3454,8199,2378,2473,96,3118,1773,227,428,2014,0,2,1,0],"city":[["440100",4.271076008106521,"广州市"],["440300",4.213781086046556,"深圳市"],["110100",4.168797469553194,"北京市"],["310100",3.7540011743091464,"上海市"],["440600",2.3945489327045095,"佛山市"],["330100",2.2103528609580088,"杭州市"],["510100",1.812602988806182,"成都市"],["441900",1.6719699982953578,"东莞市"],["320500",1.6606057162338768,"苏州市"],["350100",1.621304240771256,"福州市"],["500100",1.5739530655150862,"重庆市"],["120100",1.3049983900600413,"天津市"],["420100",1.25101805026
# ...

# %%
import json
help(json)
# Out:
# Help on package json:
#
# NAME
#     json
#
# FILE
#     e:\anaconda2\lib\json\__init__.py
#
# DESCRIPTION
#     JSON (JavaScript Object Notation) <http://json.org> is a subset of
#     JavaScript syntax (ECMA-262 3rd edition) used as a lightweight data
#     interchange format.
#
#     :mod:`json` exposes an API familiar to users of the standard library
#     :mod:`marshal` and :mod:`pickle` modules. It is the externally maintained
#     version of the :mod:`json` library contained in Python 2.6, but maintains
#     compatibility with Python 2.4 and Python 2.5 and (currently) has
#     significant performance advantages, even without using the optional C
#     extension for speedups.
#
#     Encoding basic Python object hierarchies::
#
#         >>> import json
#         >>> json.dumps(['foo', {'bar': ('baz', None, 1.0, 2)}])
#         '["foo", {"bar": ["baz", null, 1.0, 2]}]'
#         >>> print json.dumps("\"foo\bar")
#         "\"foo\bar"
# ...

# %%
jd = json.loads(m.group(1))
trend = jd['details'][0]['trend']
print trend
# Out:
# [226799, 229665, 229049, 217970, 220873, 221719, 224130, 207466, 209264, 209737, 227784, 220261, 227261, 221365, 214475, 216054, 214185, 222352, 227392, 223013, 201672, 187866, 182105, 179490, 190198, 184386, 195760, 213511, 198966, 183373, 188326, 197630, 208760, 193950, 192946, 182447, 172600, 186807, 188065, 188518, 195546, 193282, 193245, 191236, 195616, 198730, 195107, 187161, 179374, 173501, 169625, 183339, 192389, 196939, 197651, 197781, 193146, 190026, 189639, 180994, 170515, 162957, 165961, 163265, 163494, 177470, 203463, 209663, 246465, 221179, 238074, 232309, 228577, 196613, 206778, 193996, 198451, 194954, 212923, 208009, 183272, 172862, 153883, 156716, 153380, 170464, 167043, 166761, 160312, 164612, 170151, 167067, 169680, 183820, 188788, 202853, 527595, 416089, 364172, 341299, 289320, 236933, 220309, 242432, 218787, 231668, 238457, 237296, 218131, 218274, 219365, 229341, 203726, 204907, 198966, 189885, 181048, 175996, 189902, 206468, 212665, 220362, 208425, 203717, 22290
# ...

# %%
# %pylab inline
import matplotlib.pyplot as plt
plt.plot(trend)
# Out:
# Populating the interactive namespace from numpy and matplotlib
